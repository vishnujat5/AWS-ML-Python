# %% [markdown]
# <a href="https://colab.research.google.com/github/vishnujat5/AWS-ML-Python/blob/main/day1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("vishnu")
# Out:
# vishnu
